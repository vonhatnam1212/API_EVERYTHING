# %%
import spotipy
import spotipy.oauth2 as oauth2
import pandas as pd
import json
import os
pd.set_option('display.width', 30)
pd.set_option('display.max_colwidth', 30)
# Permanently changes the pandas settings
pd.set_option('display.max_rows', None)
# Đặt tùy chọn để hiển thị tất cả cột và dòng
pd.set_option('display.max_columns', None)
client_id = "db08537f8a184775b3a4be7d80333dca"
client_secret = "9e282c07297744ce8fa68d6a3da533eb"
# username = "DA"
auth_manager = oauth2.SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)
def get_track_id(track_id):
    track_id = spotify.track(track_id)
    return track_id
def get_playlist(playlist_id):
    playlist = spotify.playlist(playlist_id)
    return playlist
# Hàm để thêm dấu ngoặc vuông nếu giá trị không phải là một list
def add_brackets(value):
    if isinstance(value, list):
        if len(value) > 1:
            return [value]
        return value
    else:
        return [value]
def save_file_metadata(record, file_path):
    try:
            # Tách đường dẫn và tên file
        directory = os.path.dirname(file_path)
        if not os.path.exists(directory):
            # Nếu không tồn tại, tạo các thư mục cha
            os.makedirs(directory)
        with open(file_path, 'a') as f:
            json.dump(record, f)
            f.write(os.linesep)
    except:
        print("error with ",record)

# %%
track_id = "1CIR7UAbM5j9hcThZS8Dkz"
# print(get_track_id(track_id))
# print("------------------------------------------------")
playlist_id = "4i3lC1FqKJz9En6mfn04KZ"
# print(get_playlist(playlist_id))
track = get_track_id(track_id)
playlist = get_playlist(playlist_id)

# %%
album_track = spotify.album_tracks("2VRIiuSSYKQbmaPqSaRqTc")
album = spotify.album("2VRIiuSSYKQbmaPqSaRqTc")

# %%
top_track
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#       'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#       'id': '0TnOYISbd1XYRBk9myaseg',
#       'name': 'Pitbull',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4rG0MhkU6UojACJxkMHIXB'},
#     'href': 'https://api.spotify.com/v1/albums/4rG0MhkU6UojACJxkMHIXB',
#     'id': '4rG0MhkU6UojACJxkMHIXB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731dc7483a9fcfce54822a2f19',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021dc7483a9fcfce54822a2f19',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511dc7483a9fcfce54822a2f19',
#       'width': 64}],
# ...

# %%
top_track = spotify.artist_top_tracks("0TnOYISbd1XYRBk9myaseg")
track_url = top_track["tracks"]["external_urls"]["spotify"]
track_name = top_track["tracks"]["name"]
track_artist = top_track["tracks"]["artists"][0]["name"]
album_art_url = top_track["tracks"]["images"][0]["url"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 top_track = spotify.artist_top_tracks("0TnOYISbd1XYRBk9myaseg")
# ----> 2 track_url = top_track["tracks"]["external_urls"]["spotify"]
#       3 track_name = top_track["tracks"]["name"]
#       4 track_artist = top_track["tracks"]["artists"][0]["name"]
#
# TypeError: list indices must be integers or slices, not str

# %%
album["external_urls"]
# Out:
# {'spotify': 'https://open.spotify.com/album/2VRIiuSSYKQbmaPqSaRqTc'}

# %%
track_url = album["external_urls"]["spotify"]
track_name = album["name"]
track_artist = album["artists"][0]["name"]
album_art_url = album["images"][0]["url"]

# %%
album_art_url
# Out:
# 'https://i.scdn.co/image/ab67616d0000b2732d1df7d98ff966eafb640e81'

# %%
# Áp dụng hàm add_brackets cho từng giá trị trong dictionary
data_with_brackets = {key: add_brackets(value) for key, value in track.items()}

# %%
for key,value in data_with_brackets.items():
    print(key,":",len(value))
# Out:
# album : 1
# artists : 1
# available_markets : 1
# disc_number : 1
# duration_ms : 1
# explicit : 1
# external_ids : 1
# external_urls : 1
# href : 1
# id : 1
# is_local : 1
# name : 1
# popularity : 1
# preview_url : 1
# track_number : 1
# type : 1
# uri : 1

# %%
data_with_brackets['album'][0]["images"][0]["url"]
# Out:
# 'https://i.scdn.co/image/ab67616d0000b273128b49abebc27c16a560dae4'

# %%
pd.DataFrame.from_dict(data_with_brackets)
# Out:
#                            album  \
# 0  {'album_type': 'single', '...
#
#                          artists  \
# 0  [{'external_urls': {'spoti...
#
#                available_markets  \
# 0  [AR, AU, AT, BE, BO, BR, B...
#
#    disc_number  duration_ms  \
# 0            1       227486
#
#    explicit  \
# 0     False
#
#                external_ids  \
# 0  {'isrc': 'VNA112000087'}
#
#                    external_urls  \
# 0  {'spotify': 'https://open....
#
#                             href  \
# 0  https://api.spotify.com/v1...
#
#                        id  \
# 0  1CIR7UAbM5j9hcThZS8Dkz
#
#    is_local  \
# 0     False
#
#                           name  \
# 0  Một Giấc Mơ (feat. Kimmese)
#
#    popularity  \
# 0          44
#
#                      preview_url  \
# 0  https://p.scdn.co/mp3-prev...
#
#    track_number   type  \
# 0             1  track
#
#                              uri
# 0  spotify:track:1CIR7UAbM5j9...

# %%
path = os.path.join('mp3', 'spotify', "data_with_brackets.txt")
save_file(data_with_brackets, path)

# %%
from youtube_search import YoutubeSearch
a = YoutubeSearch("Sơn Tùng - Chúng ta của sau này", max_results=1).to_dict()

# %%
a
# Out:
# [{'id': 'zoEtcR5EW08',
#   'thumbnails': ['https://i.ytimg.com/vi/zoEtcR5EW08/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA9dXMTEq7CLh6waQR2hctXtUYf_A',
#    'https://i.ytimg.com/vi/zoEtcR5EW08/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDllRuzOCn_rtvgDkc2zSgdV8xphw'],
#   'title': 'SƠN TÙNG M-TP | CHÚNG TA CỦA TƯƠNG LAI | OFFICIAL MUSIC VIDEO',
#   'long_desc': None,
#   'channel': 'Sơn Tùng M-TP Official',
#   'duration': '4:37',
#   'views': '38.185.714 lượt xem',
#   'publish_time': '3 tuần trước',
#   'url_suffix': '/watch?v=zoEtcR5EW08&pp=ygUlU8ahbiBUw7luZyAtIENow7puZyB0YSBj4bunYSBzYXUgbsOgeQ%3D%3D'}]

# %%
best_url = "https://www.youtube.com{}".format(a[0]['url_suffix'])

# %%
[best_url]
# Out:
# ['https://www.youtube.com/watch?v=zoEtcR5EW08&pp=ygUlU8ahbiBUw7luZyAtIENow7puZyB0YSBj4bunYSBzYXUgbsOgeQ%3D%3D']
